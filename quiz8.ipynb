# %%
import math as mt

def original_vc_bound(N):
    epsilon=0.05
    dvc=10
    delta=0.05
    return ((8/(epsilon*epsilon))*math.log(4*(mt.pow(2*N,dvc)+1)/delta))


print (original_vc_bound(420000))
print (original_vc_bound(440000))
print (original_vc_bound(460000))
print (original_vc_bound(480000))
print (original_vc_bound(500000))
# Out:
# 450539.51469718025
# 452028.15519749676
# 453450.6115997635
# 454812.51926116494
# 456118.8230858131

# %%
import math as mt

def original_vc_bound(N):
    dvc=10
    delta=0.05
    return (mt.sqrt((8/N)*math.log(4*mt.pow(2*N,dvc)/delta)))

def rademacher_penalty_bound(N):
    dvc=10
    delta=0.05
    return (mt.sqrt((2/N)*math.log(2*N*mt.pow(N,dvc)/delta)) + mt.sqrt((2/N)*math.log(1/delta)) + 1/N)

def parrondo_and_van_den_broek(N):
    epsilon=0.001
    dvc=10
    delta=0.05
    convergence=0.99
    
    while (convergence < 0.99999999999999):
        old_epsilon = epsilon
        epsilon=mt.sqrt((1/N)*(2*epsilon+math.log(6*mt.pow(2*N,dvc)/delta)))
        convergence = old_epsilon / epsilon
        print (epsilon)

    return epsilon

def devroye(N):
    epsilon=0.001
    dvc=10
    delta=0.05
    convergence=0.99
    
    while (convergence < 0.99999999999999):
        old_epsilon = epsilon
        epsilon=mt.sqrt((0.5/N)*(4*epsilon*(1+epsilon)+math.log(4*mt.pow(N*N,dvc)/delta)))
        convergence = old_epsilon / epsilon
        print (epsilon)

    return epsilon

def variant_vc_bound(N):
    dvc=10
    delta=0.05
    return (mt.sqrt((16/N)*math.log(2*mt.pow(N,dvc)/mt.sqrt(delta))))

N=10000
print ("original_vc_bound =", original_vc_bound(N))
print ("rademacher_penalty_bound =", rademacher_penalty_bound(N))
print ("parrondo_and_van_den_broek =", parrondo_and_van_den_broek (N))
print ("devroye =", devroye (N))
print ("variant_vc_bound =", variant_vc_bound (N))
# Out:
# original_vc_bound = 0.28763435422082
# rademacher_penalty_bound = 0.16949304617602962
# 0.10189424285411974
# 0.1019932133790536
# 0.1019933104153902
# 0.10199331051053011
# 0.1019933105106234
# 0.10199331051062348
# parrondo_and_van_den_broek = 0.10199331051062348
# 0.09710634327225941
# 0.09721496232959755
# 0.09721509577198362
# 0.09721509593593715
# 0.0972150959361386
# 0.09721509593613885
# devroye = 0.09721509593613885
# variant_vc_bound = 0.38842124975258246

# %%
import math as mt

def original_vc_bound(N):
    dvc=10
    delta=0.05
    return (mt.sqrt((8/N)*math.log(4*mt.pow(2*N,dvc)/delta)))

def rademacher_penalty_bound(N):
    dvc=10
    delta=0.05
    return (mt.sqrt((2/N)*math.log(2*N*mt.pow(N,dvc)/delta)) + mt.sqrt((2/N)*math.log(1/delta)) + 1/N)

def parrondo_and_van_den_broek(N):
    epsilon=0.001
    dvc=10
    delta=0.05
    convergence=0.99
    
    while (convergence < 0.99999999999999):
        old_epsilon = epsilon
        epsilon=mt.sqrt((1/N)*(2*epsilon+math.log(6*mt.pow(2*N,dvc)/delta)))
        convergence = old_epsilon / epsilon
        print (epsilon)

    return epsilon

def devroye(N):
    epsilon=0.001
    dvc=10
    delta=0.05
    convergence=0.99
    
    while (convergence < 0.99999999999999):
        old_epsilon = epsilon
        epsilon=mt.sqrt((0.5/N)*(4*epsilon*(1+epsilon)+math.log(4*mt.pow(N*N,dvc)/delta)))
        convergence = old_epsilon / epsilon
        print (epsilon)

    return epsilon

def variant_vc_bound(N):
    dvc=10
    delta=0.05
    return (mt.sqrt((16/N)*math.log(2*mt.pow(N,dvc)/mt.sqrt(delta))))

N=5
print ("original_vc_bound =", original_vc_bound(N))
print ("rademacher_penalty_bound =", rademacher_penalty_bound(N))
print ("parrondo_and_van_den_broek =", parrondo_and_van_den_broek (N))
print ("devroye =", devroye (N))
print ("variant_vc_bound =", variant_vc_bound (N))
# Out:
# original_vc_bound = 6.622129876662262
# rademacher_penalty_bound = 4.2199141284787265
# 2.3586158090169116
# 2.550708697235195
# 2.5657264104807784
# 2.566896783810524
# 2.5669879719368986
# 2.566995076605964
# 2.5669956301456547
# 2.5669956732730896
# 2.5669956766332382
# 2.5669956768950346
# 2.5669956769154316
# 2.5669956769170206
# 2.5669956769171445
# 2.5669956769171542
# parrondo_and_van_den_broek = 2.5669956769171542
# 1.9124536303752804
# 2.4259125078658417
# 2.6422460312790523
# 2.739810675351706
# 2.7848927758864868
# 2.8059377591037333
# 2.8158068604154503
# 2.820444741980749
# 2.8226264014485927
# 2.823653124903425
# 2.8241364213167377
# 2.824363940313884
# 2.8244710533831445
# 2.8245214819945277
# 2.8245452239312483
# 2.824556401759614
# 2.824561664352174
# 2.824564142016893
# 2.8245653085190643
# 2.8245658577167174
# 2.824566116282971
# 2.8245662380178524
# 2.824566295331526
# 2.824566322315223
# 2.824566335019345
# 2.824566341000539
# 2.824566343816529
# 2.8245663451423177
# 2.8245663457665087
# 2.8245663460603825
# 2.8245663461987407
# 2.8245663462638806
# 2.824566346294549
# 2.8245663463089876
# 2.8245663463157857
# 2.8245663463189863
# 2.824566346320493
# 2.8245663463212023
# 2.8245663463215362
# 2.8245663463216935
# 2.8245663463217676
# 2.8245663463218023
# 2.8245663463218187
# devroye = 2.8245663463218187
# variant_vc_bound = 7.649395780933905
